# %% [markdown]
# # Matplotlib
# * 파이썬에서 chart나 plot으로 시각화 하는 패키지
# * 기능
#     - 라인 플롯(line plot)
#     - 스캐터 플롯(scatter plot)
#     - 컨투어 플롯(contour plot)
#     - 서피스 플롯(surface plot)
#     - 바 차트(bar chart)
#     - 히스토그램(histogram)
#     - 박스 플롯(box plot)

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %% [markdown]
# #### 라인 플롯 (line plot)
# - .title - 플롯의 제목
# - .show  - 플롯을 그림으로 표시

# %%
plt.title('Plot')
plt.plot([1,4,9,16])
plt.show()

# %%
plt.title('x ticks')
plt.plot([10,20,30,40,],[1,4,9,16])
plt.show()

# %%
#.title 인수에 한글 문자열을 전달하면 깨짐
    #google font - 사용가능한 한글 폰트가 따로 존재

plt.title('한글제목')
plt.plot([1,4,9,16])
plt.show()
# Out:
# C:\Users\user\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 54620 (\N{HANGUL SYLLABLE HAN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\user\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 44544 (\N{HANGUL SYLLABLE GEUL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\user\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 51228 (\N{HANGUL SYLLABLE JE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\user\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 47785 (\N{HANGUL SYLLABLE MOG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# 시스템 폰트 경로 리스트

font_list = mpl.font_manager.findSystemFonts()
print(font_list)

# %%
# 폰트 설정하기
#.family : 폰트 이름 

prop = mpl.font_manager.FontProperties(fname='원하는 폰트 경로')
plt.rcParams['font.family'] = prop.get_family()

# %% [markdown]
# #### 한글폰트 다운로드
# - 시각화에서는 폰트가 굉장히 중요
# - 무료 폰트 사이트
#     - a. 눈누: https://noonnu.cc/
#     - b. 구글 폰트: https://fonts.google.com/
#     - c. 네이버 글꼴 모음: https://hangeul.naver.com/font

# %%
#%cd : change directory

# %cd C:\\python
# Out:
# C:\python

# %% [markdown]
# #### 외부 폰트 사용하기
# - [x] path 중간에 한글 경로가 포함되는지 꼭 확인

# %%
# Add every font at the specified location

font_dir = ['./fonts']  #폰트 경로 : c:\\python\\fonts
for font in mpl.font_manager.findSystemFonts(fontpaths=font_dir):
    print(mpl.font_manager.FontProperties(fname=font).get_name())
    mpl.font_manager.fontManager.addfont(font)
# Out:
# NanumSquareRoundOTF
# NanumMyeongjoOTF YetHangul
# NanumBarunGothic YetHangul
# NanumMyeongjoOTF Eco
# NanumMyeongjoOTF Eco
# NanumGothic
# NanumSquareOTF_ac
# NanumMyeongjo
# NanumSquare
# NanumSquare Neo OTF Heavy
# NanumGothicOTF Eco
# NanumSquareOTF
# NanumMyeongjo Eco
# NanumBarunGothic
# Noto Sans KR
# NanumSquare Neo ExtraBold
# NanumSquare_ac
# NanumSquare Neo Bold
# NanumSquare
# NanumSquareRound
# NanumBarunGothicOTF
# NanumMyeongjo
# NanumMyeongjoOTF
# Nanum Pen Script OTF
# Noto Sans KR
# NanumMyeongjo Eco
# NanumSquare Neo OTF Light
# NanumSquare Neo Light
# Nanum Brush Script OTF
# Noto Sans KR
# NanumSquareRoundOTF
# Noto Sans KR
# NanumGothic Eco
# NanumBarunGothic
# NanumSquareRoundOTF
# Nanum Brush Script
# NanumBarunGothicOTF
# NanumSquareOTF_ac
# NanumGothicOTF
# D2Coding ligature
# NanumSquareOTF
# D2Coding ligature
# Nanum Pen Script
# NanumMyeongjoOTF
# NanumSquare Neo Heavy
# NanumGothicOTF
# NanumSquare Neo OTF Regular
# Noto Sans KR
# NanumMyeongjoOTF Eco
# ...

# %%
# Set font family globally

mpl.rcParams['font.family'] = 'Noto Sans KR'
print(mpl.rcParams['font.family'])
# Out:
# ['Noto Sans KR']

# %% [markdown]
# #### matplotlib.pyplot.rc()

# %% [markdown]
# #### 기본 폰트 설정

# %%
global_font = {'family' : 'NanumGothic','size':12,'weight':'bold'}

#폰트 설정
mpl.rc('font',**global_font) #pass in the fiont dict as kwarge
 #mpl.rc('fint','famliy':'Nanumgothic','size':24,'weight':'bold')와 같이 동작

# %% [markdown]
# #### 기본 폰트 확인

# %%
plt.title('한글제목')
plt.plot([10,20,30,40],[1,4,9,16])
plt.xlabel('엑스축 레이블')
plt.ylabel('와이축 레이블')
plt.show()

# %% [markdown]
# #### 개별 폰트 설정
# - fontdict

# %%
title_font = {'family' : 'NanumMyeongjo',
              'size' : 24,
              'color' : 'black'}
xlabel_font = {'family' : 'NanumBarunpen',
               'weight' : 'bold',
               'color' : 'darkred'}
ylabel_font = {'family' : 'NanumBarunGothic',
               'size' : 12,
               'weight' : 'light',
               'color': 'blue'}

# %%
plt.title('한글제목',fontdict=title_font)
plt.plot([10,20,30,40],[1,4,9,16])
plt.xlabel('엑스축 레이블', fontdict=xlabel_font)
plt.ylabel('와이축 레이블', fontdict=ylabel_font)
plt.show()

# %% [markdown]
# #### Unicode minus 표기법 설정
# - 음수 부호를 유니코드와 ASCII 중 어떤 문자를 표기할지 설정
# - axes.unicode_minus = False  : ASCII 문자 표기

# %%
#유니코드에서 음수 부호 설정
mpl.rc('axes',unicode_minus =False)

# %% [markdown]
# #### Style 설정하기
# - color
# > https://www.rapidtables.com/web/color/RGB_Color.html (RGB code)
# > https://matplotlib.org/2.0.2/examples/color/named_colors.html
#
# - marker
# > https://matplotlib.org/2.0.2/api/markers_api.html?highlight=marker#module-matplotlib.markers
#
# - line style
# > https://matplotlib.org/2.0.2/api/lines_api.html?highlight=line%20style#matplotlib.lines.Line2D.set_linestyle

# %%
plt.title('defalut 스타일의 plot')
plt.plot([10,20,30,40],[1,4,9,16])
plt.show()

# %%
plt.title("'rs--' 스타일의 plot")
plt.plot([10,20,30,40],[1,4,9,16],'rp--')
plt.show()

# %%
#선 색상(c) : 'blue' / 선 굵기(lw) : 5 / marker : circle(o)
#marker size(ms) : 15 / 마커 선 색상(mec) : g(green) / 마커 선 굵기(mew) : 5 / 마커 내부 색상(mfc) : r(red)


plt.plot([10,20,30,40],[1,4,9,16], c= 'b',
         lw = 5 , ls='--',marker='o',mec = 'g',mfc='r')
plt.title('스타일 적용 예')
plt.show()

# %% [markdown]
# #### 축의 범위 설정
# - xlim (최소,최대)
# - ylim (최소,최대)

# %%
plt.title('x축,y축의 범위 설정')
plt.plot([10,20,30,40],[1,4,9,16], c= 'b',
         lw = 5 , ls='--',marker='o',mec = 'g',mfc='r')
plt.xlim(0,50)
plt.ylim(-10,30)
plt.show()

# %% [markdown]
# #### 틱 설정하기
# - 틱(tick) : 슬롯이나 차트에서 축상의 위치 표시 지점
# - tick label : tick에 써진 숫자, 글자
# -
# > 수학적 표현 https://matplotlib.org/3.1.1/tutorials/text/mathtext.html

# %%
import numpy as np
x = np.linspace(-np.pi,np.pi,256)
c= np.cos(x)                              #코사인
plt.title('x축과 y축의 tick label 설정')
plt.plot(x,c)
plt.xticks([-np.pi,-np.pi /2, 0, np.pi  / 2, np.pi])
plt.yticks([-1,0,+1])
plt.show()

# %%
#$$사이에 수학 문자식 

x = np.linspace(-np.pi,np.pi,256)
c= np.cos(x)                              
plt.title('TeX, 문자열로 tick label 정의')
plt.plot(x,c)
plt.xticks([-np.pi,-np.pi /2, 0, np.pi  / 2, np.pi],
           [r'$-\pi$',r'$-\pi/2$',r'$0$',r'$+\pi/2$',r'$+\pi$'])
plt.yticks([-1,0,+1],['Low','Zero','High'])
plt.show()

# %% [markdown]
# #### 여러 개의 선 그리기

# %%
t = np.arange(0.,5.,0.2)
plt.title('라인 플롯에서 여러개의 선 그리기')
plt.plot(t,t,'r--', t, 0.5 * t**2, 'bs:', t , 0.2 * t**3,'g^-')
plt.show()

# %%
#복수의 plot()을 하나의 그림에 겹쳐서 사용

plt.title('복수의 plot 명령을 한 그림에서 표현')
style1 = {'c':'b', 'lw':5, 'ls':'--','marker' : 'o','ms':15, 'mec':'g','mew':5, 'mfc':'r'}
style2 = {'c':'k', 'lw':3, 'ls':':','marker' : 's','ms':10, 'mec':'m','mew':5, 'mfc':'c'}

plt.plot([1,4,9,16],**style1)
plt.plot([9,16,4,1],**style2)

plt.show()

# %% [markdown]
# #### 범례(Legend)
# - loc 키워드 인수 사용
#     - loc 사용 전에 plot마다 legend label 설정(label 키워드 인수)

# %%
x = np.linspace(-np.pi, np.pi, 256)
c,s = np.cos(x),np.sin(x)
plt.title('legend를 표시한 플롯')
plt.plot(x,c, ls='--',label ='cosine')
plt.plot(x,s, ls=':', label = 'sine')
plt.legend(loc=2)  #upper left

plt.show()

# %% [markdown]
# #### X,Y축 label

# %%
x = np.linspace(-np.pi, np.pi, 256)
c,s = np.cos(x),np.sin(x)
plt.title('Cosine Plot')
plt.plot(x,c, label ='cosine')
plt.xlabel('time')
plt.ylabel('amplitude')
plt.show()

# %%
#연습문제
    #title : 섭씨 온도와 화씨 온도
    #xlabel : 화씨 온도
    #ylabel : 섭씨 온도
    #x값은 화씨로 32이상 100미만의 정수, y 값은 섭씨로 (화씨 - 32) * 5/9

x = np.arange(32,100)
y = (x-32) * 5/9
plt.title('섭씨 온도와 화씨 온도')
plt.xlabel('화씨 온도')
plt.ylabel('섭씨 온도')
plt.plot(x,y,ls='--',c='r')
plt.show()

# %% [markdown]
# #### 내용 요약
# https://matplotlib.org/stable/tutorials/introductory/quick_start.html#parts-of-a-figure

# %% [markdown]
# ### Figure
# - 전체 그림(그래프) 의미하는 객체
# -  Axes, 특수 Artist 그룹(title, figure legends, colorbar, etc), subfigures(중첩)까지 포함 가능
#
# #### Figure 생성 방법
# - figure() : Axes없이 Figure
# - subplots() _ 인수없이 사용 : 1개의 Axes 객체 갖는 Figure
# - subplots() _ 첫 인수로 row, 두 번째 인수로 column  : grid 형태의 shape을 갖는 Axes 객체 여러개 생성

# %%
fig,ax = plt.subplots()  #Create a figure constaining a single axes
ax.plot([1,2,3,4],[1,4,2,3]) #Plot some data on the axes

# %%
fig = plt.figure()           #an empty figure with no Axes
fig, ax = plt.subplots()     #a figure with a single Axes
fig, axs = plt.subplots(2,2) #a figure with a 2x2 grid of Axes
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19608\2146703106.py in <module>
#       1 fig = plt.figure()           #an empty figure with no Axes
# ----> 2 fig, ax = plt.subplot()     #a figure with a single Axes
#       3 fig, axs = plt.subplots(2,2) #a figure with a 2x2 grid of Axes
#
# TypeError: cannot unpack non-iterable AxesSubplot object

# %%
np.random.seed(0)
f1 = plt.figure(figsize=(10,2))
plt.title('figure size: (10,2)')
plt.plot(np.random.randn(100))
plt.show()

# %%
#figure 객체 얻기 - plt.gcf()

f1 = plt.figure(1)

plt.title ('현재의 Figure 객체')
plt.plot([1,2,3,4],'ro:')

f2 = plt.gcf()
print(f1,id(f1))
print(f2,id(f2))
plt.show()
# Out:
# Figure(640x480) 2789825941568
# Figure(640x480) 2789825941568

# %% [markdown]
# #### Axes
# - tight_layout() : 플롯 간의 간격 맞추기

# %%
x1 = np.linspace(0.0,5.0)
x2 = np.linspace(0.0,2.0)
y1 = np.cos(2 * np.pi* x1) * np.exp(-x1)
y2 = np.cos(2 * np.pi * x2)

ax1 =plt.subplot(2,1,1)
plt.plot(x1,y1,'yo-')
plt.title('A tale of 2 subplots')
plt.ylabel('Damped oscillation')

ax2 = plt.subplot(2,1,2)
plt.plot(x2,y2,'r.-')
plt.xlabel('time (s)')
plt.ylabel('Undampes')

plt.tight_layout()
plt.show()

# %%
np.random.seed(0)

plt.subplot(221)
plt.plot(np.random.rand(5))
plt.title('axes 1')

plt.subplot(222)
plt.plot(np.random.rand(5))
plt.title('axes 2')

plt.subplot(223)
plt.plot(np.random.rand(5))
plt.title('axes 3')

plt.subplot(224)
plt.plot(np.random.rand(5))
plt.title('axes 4')

plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(2,2)

np.random.seed(0)
axes[0,0].plot(np.random.rand(5))
axes[0,0].set_title('axes 1')
axes[0,1].plot(np.random.rand(5))
axes[0,1].set_title('axes 2')
axes[1,0].plot(np.random.rand(5))
axes[1,0].set_title('axes 3')
axes[1,1].plot(np.random.rand(5))
axes[1,1].set_title('axes 4')

plt.tight_layout()
plt.show()

# %% [markdown]
# #### Axis (축)
# - 플롯의 가로축이나 세로축을 나타내는 객체
#
# - twinx() : 복수의 y축 생성

# %%
fig, ax0 =plt.subplots()
ax1 = ax0.twinx()
ax0.set_title('2개의 y축 한 figure에서 사용하기')
ax0.plot([10,5,2,9,7],'r-',label ='y0')
ax0.set_ylabel('y0')
ax0.grid(False)
ax1.plot([100,200,220,180,120],'g:',label='y1')
ax1.set_ylabel('y1')
ax1.grid(False)
ax0.set_xlabel('공유되는 x축')
plt.show()

# %% [markdown]
# #### Artist
# - Figure에 보이는 모든 것
# - Figure, Axes, Axis 객체, Text 객체, Line2D 객체, collections 객체, Patch 객체  포함
#     - Figure가 렌더링될 때, 모든 Artists가 그려집니다. 대부분의 Artists는 하나의 Axes       에 묶여 있습니다.
#     - [x] 이러한 Artists는 여러 Axes에 공유되거나 이동할 수 없습니다.

# %% [markdown]
# ### 바 차트
# - color = [] : bar 색상
# - xerr,yerr = error : error bar
# - alpha : 투명도 (0이면 완전 투명, 1이면 완전 불투명)

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np

y = [2,3,1]
x=['가','나','다']
plt.title('Bar Chart')
plt.bar(x,y)
plt.ylabel('빈도수')
plt.xlabel('가나다')
plt.show()

# %%
#bar마다 색상 적용

y = [2,3,1]
x=['가','나','다']
color =['red','green','blue']

plt.title('Bar Chart')
plt.bar(x,y,color=color)
plt.ylabel('빈도수')
plt.xlabel('가나다')
plt.show()

# %%
#error bar

np.random.seed(0)

people = ['몽룡','춘향','방자','향단']
performance = 3 +10 *np.random.rand(len(people))
error =np.random.rand(len(people))

plt.title('Barh Chart')
plt.barh(people,performance,xerr=error,alpha = 0.4)
plt.xlabel('x라벨')
plt.show()

# %%
bar_chart = titanic['alive'].value_counts()
bar_chart.rename({'no':'사망자','yes':'생존자'},inplace =True)
bar_chart

alive = bar_chart.index
value = bar_chart.values
bar_colors = ['red','green']

plt.title('타이타닉호 생존 여부')
plt.barh(alive,value,color = bar_colors)
plt.xlabel('인원 수')
plt.show()

# %% [markdown]
# ### 파이 차트
# - 카테고리 별 값의 상대적인 비교할 때

# %%
labels = ['월세','전세','자가','기타']
sizes = [15,30,45,10]
colors = ['yellowgreen','gold','lightskyblue','lightcoral']
explode = (0,0,0.1,0)
plt.title('Pie Chart')
plt.pie(sizes, explode=explode, labels=labels,colors=colors,
        autopct='%1.1f%%', shadow=True,startangle=90)
plt.axis('equal')    #원의 형태를 유지
plt.show()

# %%
#연습문제
    #타이타닉 호 승객을 나이 그룹으로 나누고 
    #나이 그룹의 승객 비율을 파이 차트로 출력

bins = [0, 20, 30, 50, 70, 100]
labels = ["미성년자", "청년", "장년", "중년", "노년"]
explode = (0.1, 0, 0, 0, 0)
colors = ["yellowgreen", "gold", "lightskyblue", "lightcoral", "orange"]

age = titanic.age.dropna()
sizes = pd.cut(age,bins,labels=labels)
sizes_rate = sizes.value_counts(normalize = True)
sizes_rate

plt.pie(sizes_rate, explode=explode, labels=sizes_rate.index, colors=colors,
        autopct='%1.1f%%', shadow=True,startangle=90)
plt.show()

#레이블 순서 고려 중요! labels=sizes_rate.index

# %% [markdown]
# ### 히스토그램

# %%
np.random.seed(0)
x =np.random.randn(1000)
plt.title('Histogram')
arrays, bins, patches= plt.hist(x,bins=10)
plt.show()

# %%
arrays
# Out:
# array([  9.,  20.,  70., 146., 217., 239., 160.,  86.,  38.,  15.])

# %%
bins
# Out:
# array([-3.04614305, -2.46559324, -1.88504342, -1.3044936 , -0.72394379,
#        -0.14339397,  0.43715585,  1.01770566,  1.59825548,  2.1788053 ,
#         2.75935511])

# %% [markdown]
# ### 스캐터 플롯
# - 2차원 데이터 집합의 상관관계
# - scatter()
#
# #### 버블 차트
# - 3차원 이상 데이터 집합의 상관관계
# - 점 하나의 크기, 색깔을 이용해 구분

# %%
np.random.seed(0)
x = np.random.normal(0,1,100)
y = np.random.normal(0,1,100)
plt.title('Scatter Plot')
plt.scatter(x,y)
plt.show()

# %%
N = 30
np.random.seed(0)
x = np.random.rand(N)
y1 = np.random.rand(N)
y2 = np.random.rand(N)
y3 = np.pi * (15 * np.random.rand(N))**2
plt.title('Bubble Chart')
plt.scatter(x,y1, c=y2, s=y3)
plt.show()

# %% [markdown]
# ### imshow
# - 2차원 자료의 크기를 색깔로 표시

# %%
from sklearn.datasets import load_digits
digits = load_digits()
x = digits.images[0]
x
# Out:
# array([[ 0.,  0.,  5., 13.,  9.,  1.,  0.,  0.],
#        [ 0.,  0., 13., 15., 10., 15.,  5.,  0.],
#        [ 0.,  3., 15.,  2.,  0., 11.,  8.,  0.],
#        [ 0.,  4., 12.,  0.,  0.,  8.,  8.,  0.],
#        [ 0.,  5.,  8.,  0.,  0.,  9.,  8.,  0.],
#        [ 0.,  4., 11.,  0.,  1., 12.,  7.,  0.],
#        [ 0.,  2., 14.,  5., 10., 12.,  0.,  0.],
#        [ 0.,  0.,  6., 13., 10.,  0.,  0.,  0.]])

# %%
plt.title('mnist digits;0')
plt.imshow(x,interpolation='nearest',cmap=plt.cm.bone_r)   
plt.xticks([])
plt.yticks([])
plt.grid(False)
plt.subplots_adjust(left=0.35,right=0.65,bottom = 0.35, top=0.65)
plt.show()

# %% [markdown]
# #### cmap
# - 데이터 수치를 색으로 바꾸는 함수
# - plt.cm 속성으로 포함

# %%
dir(plt.cm)[:10]
# Out:
# ['Accent',
#  'Accent_r',
#  'Blues',
#  'Blues_r',
#  'BrBG',
#  'BrBG_r',
#  'BuGn',
#  'BuGn_r',
#  'BuPu',
#  'BuPu_r']

# %%
fig, axes = plt.subplots(1, 4, figsize=(12, 3),
                        subplot_kw={'xticks': [], 'yticks': []})
axes[0].set_title("plt.cm.Blues")
axes[0].imshow(x, interpolation='nearest', cmap=plt.cm.Blues)
axes[1].set_title("plt.cm.Blues_r")
axes[1].imshow(x, interpolation='nearest', cmap=plt.cm.Blues_r)
axes[2].set_title("plt.cm.BrBG")
axes[2].imshow(x, interpolation='nearest', cmap=plt.cm.BrBG)
axes[3].set_title("plt.cm.BrBG_r")
axes[3].imshow(x, interpolation='nearest', cmap=plt.cm.BrBG_r)
plt.show()

# %%
methods = {
    None, 'none', 'nearest', 'bilinear', 'bicubic', 'spline16', 'spline36',
    'hanning', 'hamming', 'hermite', 'kaiser', 'quadric', 'catrom', 'gaussian',
    'bessel', 'mitchell', 'sinc', 'lanczos'
}
fig, axes = plt.subplots(3, 6, figsize = (12, 6),
                         subplot_kw = {'xticks' : [], 'yticks' : []})
for ax, interp_method in zip(axes.flat, methods):
    ax.imshow(x, cmap = plt.cm.bone_r, interpolation = interp_method)
    ax.set_title(interp_method)
    
plt.show()

# %% [markdown]
# ### 컨투어 플롯
# - 3차원 자료를 등고선으로 표시

# %%
def f(x,y):
    return(1-x/2+x ** 5  + y ** 3) * np.exp(-x ** 2 -y ** 2)

n =256
x = np.linspace(-3,3,n)
y = np.linspace(-3,3,n)
XX,YY = np.meshgrid(x,y)
ZZ =f(XX,YY)

plt.title('Contour plots')
plt.contourf(XX,YY,ZZ, alpha =.75, camp='jet')
plt.contour(XX,YY,ZZ,colors='black')
plt.show()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_19608\1928791207.py:11: UserWarning: The following kwargs were not used by contour: 'camp'
#   plt.contourf(XX,YY,ZZ, alpha =.75, camp='jet')

# %% [markdown]
# ### 3D 서비스 플롯
# - Axes3D라는 3차원 전용 axes를 생성하여 입체적으로 표시
# - plot_wireframe(), plot_surface() 명령 사용

# %%
from mpl_toolkits.mplot3d import Axes3D
x = np.arange(-4,4,0.25)
y = np.arange(-4,4,0.25)
XX,YY = np.meshgrid(x,y)
RR = np.sqrt(XX**2 + YY**2)
ZZ = np.sin(RR)

fig= plt.figure()
ax = Axes3D(fig)
ax.set_title('3D Surface Plot')
ax.plot_surface(XX,YY,ZZ,rstride=1,cstride=1,cmap='hot')
plt.show()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_19608\920396570.py:9: MatplotlibDeprecationWarning: Axes3D(fig) adding itself to the figure is deprecated since 3.4. Pass the keyword argument auto_add_to_figure=False and use fig.add_axes(ax) to suppress this warning. The default value of auto_add_to_figure will change to False in mpl3.5 and True values will no longer work in 3.6.  This is consistent with other Axes classes.
#   ax = Axes3D(fig)
